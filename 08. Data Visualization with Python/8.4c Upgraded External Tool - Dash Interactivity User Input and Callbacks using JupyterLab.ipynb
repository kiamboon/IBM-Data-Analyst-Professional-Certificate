# %% [markdown]
# ⚠️ Last line unable to execute
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/logo.png" width="300" alt="cognitiveclass.ai logo" />
# </center>

# %% [markdown]
# # Objectives
#
# In this lab, you will work on Dash Callbacks.
#
# ## Dataset Used
#
# [Airline Reporting Carrier On-Time Performance](https://developer.ibm.com/exchanges/data/all/airline/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) dataset from [Data Asset eXchange](https://developer.ibm.com/exchanges/data/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# ## Lab Question
#
# Extract average monthly arrival delay time and see how it changes over the year.
#
# ## Dash Application Creation
#
# ### Todo for the lab question
#
# 1.  Import required libraries, read the airline data, and create an application layout
# 2.  Add title to the dashboard using HTML H1 component
# 3.  Add a HTML division and core text input component inside the division. Provide an input component id and a default value to the component.
# 4.  Add a HTML dividion and core graph component. Provide a graph component id.
# 5.  Add callback decorator and provide input and output parameters.
# 6.  Define callback function, perform computation to extract required information, create the graph, and update the layout.
# 7.  Run the app
#
# ## Hints
#
# General examples can be found [here](https://dash.plotly.com/layout?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01).
#
# -   For step 1 (only review), this is very specific to running app from Jupyerlab.
#
#     -   For Jupyterlab,we will be using `jupyter-dash` library. Adding `from jupyter_dash import JupyterDash` import statement.
#     -   Instead of creating dash application using `app = dash.Dash()`, we will be using `app = JupyterDash(__name__)`.
#     -   Use pandas to read the airline data.
# -   For step 2,
#
#     -   [Plotly H1 HTML Component](https://dash.plotly.com/dash-html-components/h1?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#     -   Title as `Airline Performance Dashboard`
#     -   Use `style` parameter and make the title center aligned, with color code `#503D36`, and font-size as 40. Check `More about HTML` section [here](https://dash.plotly.com/layout?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01).
# -   For step 3,
#
#     -   Add [dcc input](https://dash.plotly.com/dash-core-components/input?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and provide id as `input-year`. Use `style` parameter and assign height of the inout box to be `50px` and font-size to be `35`.
#     -   HTML [Div](https://dash.plotly.com/dash-html-components/div?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and provide id as `line-plot`. Use `style` parameter and assign font-size as `40`.
# -   For step 4,
#
#     -   Core [graph](https://dash.plotly.com/dash-core-components/graph?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and assign id as `line-plot`.
# -   For 5 and 6,
#
#     -   Basic [callback](https://dash.plotly.com/basic-callbacks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## App Skeleton
#
# ```python
#
# import dash
# ....
# ....
# from jupyter_dash import JupyterDash
#
#
# app = JupyterDash(__name__)
# JupyterDash.infer_jupyter_proxy_config()
#
#
# app.layout = html.Div(children=[html.H1(.......),
#                                 html.Div(['Input:', dcc.Input(id='..', value='..', type='..', style={})], style={}),
#                                 html.Br(),
#                                 html.Br(),
#                                 html.Div(dcc.Graph(id='..')),
#                                ])
#
# if __name__ == '__main__':
#     app.run_server(mode="inline", host="localhost")
#
# ```

# %%
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install dash dash_core_components dash_html_components jupyter_dash
# !pip install --upgrade plotly
# Out:
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
# Collecting Flask>=1.0.4
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
# Collecting flask-compress
#   Using cached Flask_Compress-1.9.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from dash==1.19.0) (4.14.3)
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Requirement already satisfied: click>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Collecting brotli
#   Using cached Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\user\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.3.3)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84011 sha256=03b61cbc1989eaa4756941f7f4c43de761f02dc473965ba6731c4a6ec9527759
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e7\27\2f\a9f9bf858843b5365bcb311a80f0b2379737caf4ec50b2ae3a
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527011 sha256=3779835189822f1ddb109d1b4e9a3f12c57abeb06aab05669214792c9268e07a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e3\e6\0e\759ca580c568aad2436521fa6df67f53a141dc1ab8f040c4c7
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427831 sha256=9be2b54d2c8e296d2722f20ba429aa4eefc34ea3c1d42f72028e71a611ff18c1
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8a\bc\a8\7ad1d354777cfe77413fd7a092e07d7cc82f88f98997f4c463
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014872 sha256=525fe84a4e22a3effdeefb0972364c2bad3e0f505217bc0ede699451cd79fa14
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\08\94\09\e11ba8ae5d97e1c8ff5be0ac1f7cf42642eec6ea94ed1e4b44
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839869 sha256=fa1b55843f28dbdc5f34bbed63cee62d3e56a3fc1d726d3b9a7d7db1f6176401
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\cc\1d\a0\720dcf854e410eddbe44f8434f4d3a6332fdd085178eeac4f9
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: Werkzeug, itsdangerous, Flask, brotli, flask-compress, dash-table, dash-renderer, dash-html-components, dash-core-components, dash
# Successfully installed Flask-2.0.1 Werkzeug-2.0.1 brotli-1.0.9 dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-renderer-1.9.0 dash-table-4.11.2 flask-compress-1.9.0 itsdangerous-2.0.1
# Collecting jupyter_dash
#   Using cached jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: flask in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (2.0.1)
# Requirement already satisfied: dash in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Collecting ansi2html
#   Using cached ansi2html-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: retrying in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.14.3)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\user\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: click>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\user\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\user\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\user\anaconda3\lib\site-packages (from flask->jupyter_dash) (3.0.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=7.1.2->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: brotli in c:\users\user\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tornado>=4.2 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.9.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.9)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: parso>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Installing collected packages: ansi2html, jupyter-dash
# Successfully installed ansi2html-1.6.0 jupyter-dash-0.4.0
# Requirement already satisfied: dash in c:\users\user\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash_core_components in c:\users\user\anaconda3\lib\site-packages (1.15.0)
# Requirement already satisfied: dash_html_components in c:\users\user\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: jupyter_dash in c:\users\user\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\user\anaconda3\lib\site-packages (from dash) (4.11.2)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from dash) (4.14.3)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\user\anaconda3\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: flask-compress in c:\users\user\anaconda3\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\user\anaconda3\lib\site-packages (from dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.0.0)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: ansi2html in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: retrying in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: brotli in c:\users\user\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.9)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.9.0)
# Requirement already satisfied: parso>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\user\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from plotly) (1.15.0)

# %%
# Import required libraries
import pandas as pd
import plotly.graph_objects as go
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output

# Create a dash application
app = dash.Dash(__name__)

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv", 
                            encoding = "ISO-8859-1",
                            dtype = {"Div1Airport": str, "Div1TailNum": str, 
                                   "Div2Airport": str, "Div2TailNum": str})

# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add a html.Div and core input text component
# Finally, add graph component.
app.layout = html.Div(children = [html.H1("Airline Performance Dashboard",
                                          style = {"textAlign": "center", "color": "#503D36",
                                                   "font-size": 40}),
                                  html.Div(["Input Year:", dcc.Input(id = "input-year", value = "2010",
                                                                     type = "number", style = {"height": "50px",
                                                                                               "font-size": 35}),],
                                           style = {"font-size": 40}),
                                  html.Br(),
                                  html.Br(),
                                  html.Div(dcc.Graph(id = "line-plot")),
                                 ])

# add callback decorator
@app.callback( Output(component_id = "line-plot", component_property = "figure"),
               Input(component_id = "input-year", component_property = "value"))

# Add computation to callback function and return graph
def get_graph(entered_year):
    # Select 2019 data
    df =  airline_data[airline_data["Year"] == int(entered_year)]
    
    # Group the data by Month and compute average over arrival delay time.
    line_data = df.groupby("Month")["ArrDelay"].mean().reset_index()

    fig = go.Figure(data = go.Scatter(x = line_data["Month"], y = line_data["ArrDelay"], mode = "lines", marker = dict(color = "green")))
    fig.update_layout(title = "Month vs Average Flight Delay Time", xaxis_title = "Month", yaxis_title = "ArrDelay")
    return fig

# Run the app
if __name__ == "__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %%
# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
# import plotly.graph_objects as go

# %%
from jupyter_dash import JupyterDash

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
 # needs to be run again in a separate cell due to a jupyterdash bug
JupyterDash.infer_jupyter_proxy_config()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-0283ffed0d80> in <module>
#       1 # needs to be run again in a separate cell due to a jupyterdash bug
# ----> 2 JupyterDash.infer_jupyter_proxy_config()
#
# ~\anaconda3\lib\site-packages\jupyter_dash\jupyter_app.py in infer_jupyter_proxy_config(cls)
#      71         else:
#      72             # Assume classic notebook or JupyterLab
# ---> 73             _request_jupyter_config()
#      74
#      75     def __init__(self, name=None, server_url=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\jupyter_dash\comms.py in _request_jupyter_config(timeout)
#      60         if (time.time() - t0) > timeout:
#      61             # give up
# ---> 62             raise EnvironmentError(
#      63                 "Unable to communicate with the jupyter_dash notebook or JupyterLab \n"
#      64                 "extension required to infer Jupyter configuration."
#
# OSError: Unable to communicate with the jupyter_dash notebook or JupyterLab
# extension required to infer Jupyter configuration.

# %%
# Create a dash application
app = JupyterDash(__name__)

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv", 
                            encoding = "ISO-8859-1",
                            dtype = {"Div1Airport": str, "Div1TailNum": str, 
                                   "Div2Airport": str, "Div2TailNum": str})

# To do
# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add a html.Div and core input text component
# Finally, add graph component.


# add callback decorator

# Add computation to callback function and return graph
def get_graph(entered_year):
    return fig

# %%
# Run the app (# Try changing the port from 8050 to 8004.)
if __name__ == "__main__":
    app.run_server(mode='jupyterlab', port = 8090, dev_tools_ui=True, #debug=True,
              dev_tools_hot_reload =True, threaded=True)
    # app.run_server(debug = True)
    # app.run_server(mode = "inline", host = "localhost", debug = False, dev_tools_ui = False, dev_tools_props_check = False)
    # app.run_server(mode="inline", host="localhost", port = 8017, debug = True)
    # app.run_server(mode = "external", host = "localhost")
    # app.run_server(debug = False, port = 8888)
# Out:
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_shutdown_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_shutdown_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37524, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37526, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37528, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37532, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37534, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37538, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37544, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37552, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37560, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37568, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37572, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37576, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37580, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37584, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37588, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/flask/app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': 'localhost:8050', 'HTTP_USER_AGENT': 'python-requests/2.23.0', 'PATH_INFO': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'QUERY_STRING': '', 'RAW_URI': '/_alive_1e9b3ad4-524c-4daa-84d8-2093edb22991', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 37598, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# /usr/local/lib/python3.7/dist-packages/flask/app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1994             self._got_first_request = True
#    1995
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1093             self._walk_assets_directory()
#    1094
# -> 1095         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x7fab36f82830>
#         self.layout = None
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x7fab363929d0>>
#    1096
#    1097         self._generate_scripts_html()
#
# /usr/local/lib/python3.7/dist-packages/dash/_validate.py in validate_layout(layout=None, layout_value=None)
#     342             Make sure to set the `layout` attribute of your application
#     343             before running the server.
# --> 344             """
#     345         )
#     346
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-cc3a840a50ba> in <module>()
#       6     # app.run_server(debug = False, port = 8888)
#       7     # app.run_server(mode="inline", host="localhost", port = 8099, debug = False, dev_tools_ui=False, dev_tools_props_check=False)
# ----> 8     app.run_server(mode="inline", host="localhost",  debug=False, dev_tools_ui=False, dev_tools_props_check=False)
#
# /usr/local/lib/python3.7/dist-packages/jupyter_dash/jupyter_app.py in run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     317                 )
#     318
# --> 319         wait_for_app()
#     320
#     321         if JupyterDash._in_colab:
#
# /usr/local/lib/python3.7/dist-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# /usr/local/lib/python3.7/dist-packages/retrying.py in call(self, fn, *args, **kwargs)
#     210                 if not self._wrap_exception and attempt.has_exception:
#     211                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 212                     raise attempt.get()
#     213                 else:
#     214                     raise RetryError(attempt)
#
# /usr/local/lib/python3.7/dist-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# /usr/local/lib/python3.7/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /usr/local/lib/python3.7/dist-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# /usr/local/lib/python3.7/dist-packages/jupyter_dash/jupyter_app.py in wait_for_app()
#     313                     "Address '{url}' already in use.\n"
#     314                     "    Try passing a different port to run_server.".format(
# --> 315                         url=url
#     316                     )
#     317                 )
#
# OSError: Address 'http://localhost:8050' already in use.
#     Try passing a different port to run_server.

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- The answer is below:
#
# # Create a dash application
# app = JupyterDash(__name__)
#
# # Read the airline data into pandas dataframe
# airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv',
#                             encoding = "ISO-8859-1",
#                             dtype={'Div1Airport': str, 'Div1TailNum': str,
#                                    'Div2Airport': str, 'Div2TailNum': str})
#
# # TODO
# # Get the layout of the application and adjust it.
# # Create an outer division using html.Div and add title to the dashboard using html.H1 component
# # Add a html.Div and core input text component
# # Finally, add graph component.
# app.layout = html.Div(children=[ html.H1('Airline Performance Dashboard',
#                                 style={'textAlign': 'center', 'color': '#503D36',
#                                 'font-size': 40}),
#                                 html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010',
#                                 type='number', style={'height':'50px', 'font-size': 35}),],
#                                 style={'font-size': 40}),
#                                 html.Br(),
#                                 html.Br(),
#                                 html.Div(dcc.Graph(id='line-plot')),
#                                 ])
#
# # add callback decorator
# @app.callback( Output(component_id='line-plot', component_property='figure'),
#                Input(component_id='input-year', component_property='value'))
#
# # Add computation to callback function and return graph
# def get_graph(entered_year):
#     # Select 2019 data
#     df =  airline_data[airline_data['Year']==int(entered_year)]
#
#     # Group the data by Month and compute average over arrival delay time.
#     line_data = df.groupby('Month')['ArrDelay'].mean().reset_index()
#
#     fig = go.Figure(data=go.Scatter(x=line_data['Month'], y=line_data['ArrDelay'], mode='lines', marker=dict(color='green')))
#     fig.update_layout(title='Month vs Average Flight Delay Time', xaxis_title='Month', yaxis_title='ArrDelay')
#     return fig
#
# # Run the app
# if __name__ == '__main__':
#     app.run_server(mode="inline", host="localhost")
#
# -->

# %% [markdown]
# ## Summary
#
# Congratulations for completing your dash interactivity lab.
#
# In this lab, you have learnt how to make dash HTML and core components interact with each other for creating dashboard.

# %% [markdown]
# ## Author
#
# [Saishruthi Swaminathan](https://www.linkedin.com/in/saishruthi-swaminathan/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## Changelog
#
# | Date       | Version | Changed by | Change Description                   |
# | ---------- | ------- | ---------- | ------------------------------------ |
# | 12-18-2020 | 1.0     | Nayef      | Added dataset link and upload to Git |

# %%
msg = "sentosa"

msg[0]

# %%
msg[-1]
